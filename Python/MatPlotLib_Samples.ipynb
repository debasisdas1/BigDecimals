# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import random

# %%
x = ["Phone","TV","Laptop","Accessory"]
y = np.random.uniform(1000,1200,4)
fig = plt.figure(figsize = (8, 4))
plt.plot(x,y)
plt.xlabel("Products")
plt.ylabel("Sale")
plt.title('Products Sale')
plt.show()

# %%
plt.bar(x, y, color ='maroon',
        width = 0.4)
plt.show()

# %%
barWidth = 0.2
fig = plt.subplots(figsize =(12, 8))
 
# set height of bar
phone = [12, 30, 1, 8, 22]
tv = [28, 6, 16, 5, 10]
home_theater = [29, 3, 24, 25, 17]
 
# Set position of bar on X axis
br1 = np.arange(len(phone))
br2 = [x + barWidth for x in br1]
br3 = [x + barWidth for x in br2]

print(br1,br2,br3)
 
# Make the plot
plt.bar(br1, IT, color ='r', width = barWidth,
        edgecolor ='grey', label ='IT')
plt.bar(br2, ECE, color ='g', width = barWidth,
        edgecolor ='grey', label ='ECE')
plt.bar(br3, CSE, color ='b', width = barWidth,
        edgecolor ='grey', label ='CSE')
 
# Adding Xticks
plt.xlabel('Branch', fontweight ='bold', fontsize = 15)
plt.ylabel('Students passed', fontweight ='bold', fontsize = 15)
plt.xticks([r + barWidth for r in range(len(IT))],
        ['2015', '2016', '2017', '2018', '2019'])
 
plt.legend()
plt.show()
# Out:
# [0 1 2 3 4] [0.2, 1.2, 2.2, 3.2, 4.2] [0.4, 1.4, 2.4000000000000004, 3.4000000000000004, 4.4]
